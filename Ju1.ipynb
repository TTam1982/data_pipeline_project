# %%
import sqlite3
import pandas as pd

# Kết nối tới SQLite database
conn = sqlite3.connect("data.db")

# Thực hiện truy vấn SQL và lưu kết quả vào DataFrame
df = pd.read_sql_query("SELECT * FROM delegations", conn)

# Kiểm tra số lượng dòng trong DataFrame
# print(f"Number of rows in DataFrame: {len(df)}")
# df.iloc[:100]
# Thiết lập số lượng dòng hiển thị tối đa
# pd.set_option('display.max_rows', 500)

# Hiển thị DataFrame
df
# Out:
#                                           Company Name           First Name  \
# 0                                                 9Pay                 Toan
# 1                                             9Pay JSC                 Anne
# 2                                             9Pay SJC            Hong Thuy
# 3                                             ABB Bank               Thuong
# 4                                   Academy Of Finance                 Lien
# 5                                                  ACB            Manh Toan
# 6                                                 ACBS              Minh Hà
# 7                                             Agribank           Giang Tinh
# 8                                                  AIA                Hoàng
# 9                                         AIA Viet Nam         Thi Thu Hien
# 10                                         AIA Vietnam        Thi Khanh Hoa
# ...
